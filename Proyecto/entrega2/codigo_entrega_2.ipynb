# %%
import requests
import pandas as pd
import time
import math
from pathlib import Path
from pandas.io.parsers import read_csv
from google.colab import drive
import json

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# JUNTAR TODOS LOS DATOS Y FILTRAR

# %%
d1 = read_csv('/content/drive/MyDrive/PD1/d_17_02.csv', header=0)
d2 = read_csv('/content/drive/MyDrive/PD1/d_1_03.csv', header=0)
d3 = read_csv('/content/drive/MyDrive/PD1/d_21_02.csv', header=0)
d4 = read_csv('/content/drive/MyDrive/PD1/d_26_02.csv', header=0)
d5 = read_csv('/content/drive/MyDrive/PD1/d_28_02.csv', header=0)
d6 = read_csv('/content/drive/MyDrive/PD1/datos_5_03.csv', header=0)

# %%
# Juntar todos los dataframes en uno solo
df_total = pd.concat([d1, d2, d3, d4, d5, d6], ignore_index=True)
print(len(df_total))

# Contar las filas que están duplicadas
num_duplicados = df_total.duplicated().sum()
print("Filas duplicadas", num_duplicados)

# Eliminar los duplicados del dataframe (inplace=True para que los elimine sobre el propio dataframe)
df_total.drop_duplicates(inplace=True)
print('Num filas sin duplicados', len(df_total))

df_total = df_total.drop(columns = ['id', 'test', 'url','images', 'promoters',
                                    'type', 'locale', '_links', 'seatmap'])
# Out:
# 5129
# Filas duplicadas 2637
# Num filas sin duplicados 2492

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2492 entries, 0 to 5128
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2492 non-null   object
#  1   sales            2492 non-null   object
#  2   dates            2492 non-null   object
#  3   classifications  2492 non-null   object
#  4   promoter         2489 non-null   object
#  5   priceRanges      2483 non-null   object
#  6   _embedded        2492 non-null   object
# dtypes: object(7)
# memory usage: 155.8+ KB

# %%
# lista de strings a filtrar
strings_filtrar = ['film', 'servicio de autobús', 'festival', 'vip', 'meet', 'meet & greet', 'ticket', 'package', 'musical']

# Filtrar
for string in strings_filtrar:
    df_total = df_total[~df_total['name'].str.lower().str.contains(string)]

print(len(df_total))
# Out:
# 1911

# %%
df_total.sample(5)
# Out:
#                             name  \
# 4095                Black Coffee
# 3511  JP Saxe - A Grey Area Tour
# 3079                Black Coffee
# 4651              New Model Army
# 3045                   Tom Jones
#
#                                                   sales  \
# 4095  {'public': {'startDateTime': '2024-02-23T16:30...
# 3511  {'public': {'startDateTime': '2023-08-25T08:00...
# 3079  {'public': {'startDateTime': '2024-02-23T16:30...
# 4651  {'public': {'startDateTime': '2024-03-01T09:00...
# 3045  {'public': {'startDateTime': '2024-01-11T14:40...
#
#                                                   dates  \
# 4095  {'start': {'localDate': '2024-08-03', 'localTi...
# 3511  {'start': {'localDate': '2024-04-14', 'localTi...
# 3079  {'start': {'localDate': '2024-06-22', 'localTi...
# 4651  {'access': {'startDateTime': '2024-11-10T19:30...
# 3045  {'access': {'startDateTime': '2024-07-23T20:00...
#
#                                         classifications  \
# 4095  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 3511  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 3079  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 4651  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 3045  [{'primary': True, 'segment': {'id': 'KZFzniwn...
#
#                                                promoter  \
# 4095      {'id': '5895', 'name': 'Only Tickets, S.L.,'}
# 3511  {'id': '2729', 'name': 'Live Nation España S.A...
# 3079      {'id': '5895', 'name': 'Only Tickets, S.L.,'}
# 4651      {'id': '2761', 'name': 'Sergio Solís Gálvez'}
# 3045  {'id': '6253', 'name': 'Tickex Experience, S.L.'}
#
#                                             priceRanges  \
# 4095  [{'type': 'standard including fees', 'currency...
# 3511  [{'type': 'standard', 'currency': 'EUR', 'min'...
# 3079  [{'type': 'standard including fees', 'currency...
# 4651  [{'type': 'standard', 'currency': 'EUR', 'min'...
# 3045  [{'type': 'standard including fees', 'currency...
#
#                                               _embedded
# 4095  {'venues': [{'name': 'Hï Ibiza', 'type': 'venu...
# 3511  {'venues': [{'name': 'Sala Razzmatazz 2', 'typ...
# 3079  {'venues': [{'name': 'Hï Ibiza', 'type': 'venu...
# 4651  {'venues': [{'name': 'Sala Razzmatazz 2', 'typ...
# 3045  {'venues': [{'name': 'Auditorio Starlite', 'ty...

# %% [markdown]
# Una vez eliminados algunos eventos por el nombre subdividimos las columnas que tenemos. Sin embargo, vemos que los valores de las filas usan comillas simples (') en vez de dobles (") y los valores booleanos en mayúsculas (False, True) en vez de minúsculas (false, true). Será necesario usar una función que corrija estos fallos y así podamos usar la función json.loads que nos permite convertir cadenas a diccionarios.

# %%
def corregir_json(json_str):
    # Convertir a cadena de texto si no es una cadena
    if isinstance(json_str, str):
        # Reemplazar comillas simples por comillas dobles
        corregida = json_str.replace("'", '"')
        # Reemplazar "True" por "true" y "False" por "false"
        corregida = corregida.replace("True", "true")
        corregida = corregida.replace("False", "false")
        return json.loads(corregida)
    else:
        return json_str


def corregir_columnas(df, columnas):
    for columna in columnas:
        df[columna] = df[columna].apply(corregir_json)
    return df

# Lista de columnas a corregir
columnas_a_corregir = ['sales', 'dates', 'classifications', 'promoter', 'priceRanges']

# Aplicar la función de corrección a las columnas especificadas
df_1 = corregir_columnas(df_total, columnas_a_corregir)

# %% [markdown]
# Usamos diferentes funciones para subdivdir las columnas.

# %%
# Para obtener la fecha y hora de inicio del concierto como tal
def obtener_start_datetime(fila):
    if 'access' in fila['dates'] and 'startDateTime' in fila['dates']['access']:
      return fila['dates']['access']['startDateTime']
    elif 'start' in fila['dates'] and 'dateTime' in fila['dates']['start']:
      return fila['dates']['start']['dateTime']
    else:
      return None

# Para obtener la fecha y hora del inicio de la venta del concierto
def obtener_sales_datetime(fila):
    return fila['sales']['public'].get('startDateTime')

# Para obtener la fecha y hora del final de la venta del concierto
def obtener_end_datetime(fila):
    return fila['sales']['public'].get('endDateTime')

def obtener_min_price(fila):
    if 'priceRanges' in fila and isinstance(fila['priceRanges'], list) and fila['priceRanges']:
        for price_range in fila['priceRanges']:
            if price_range.get('type') == 'standard':
                return price_range['min']
    return None

def obtener_max_price(fila):
    if 'priceRanges' in fila and isinstance(fila['priceRanges'], list) and fila['priceRanges']:
        for price_range in fila['priceRanges']:
            if price_range.get('type') == 'standard':
                return price_range['max']
    return None

def obtener_promotor(fila):
    if 'promoter' in fila and isinstance(fila['promoter'], dict):
        return fila['promoter'].get('name')
    else:
        return None

def obtener_genero(fila):
    if isinstance(fila['classifications'], list) and fila['classifications']:
        # Verifica si classifications es una lista no vacía
        for item in fila['classifications']:
            if 'genre' in item and isinstance(item['genre'], dict):
                return item['genre'].get('name')
    return None

def obtener_subgenero(fila):
    if isinstance(fila['classifications'], list) and fila['classifications']:
        for item in fila['classifications']:
            if 'subGenre' in item and isinstance(item['subGenre'], dict):
                return item['subGenre'].get('name')
    return None

# %%
df_1['startDateTime'] = df_1.apply(obtener_start_datetime, axis=1)
df_1['sales_datetime'] = df_1.apply(obtener_sales_datetime, axis=1)
df_1['end_datetime'] = df_1.apply(obtener_end_datetime, axis=1)
df_1['min_price'] = df_1.apply(obtener_min_price, axis=1)
df_1['max_price'] = df_1.apply(obtener_max_price, axis=1)
df_1['genero'] = df_1.apply(obtener_genero, axis=1)
df_1['subgnero'] = df_1.apply(obtener_subgenero, axis=1)
df_1['promoter'] = df_1.apply(obtener_promotor, axis=1)

# %%
df_1 = df_1.reset_index(drop=True)
df_1.sample(5)
# Out:
#                               name  \
# 1098                 Orphaned Land
# 963   Tale of Us present Afterlife
# 1079                        Camilo
# 584               Miriam Rodríguez
# 1569                   Luis Miguel
#
#                                                   sales  \
# 1098  {'public': {'startDateTime': '2023-08-24T18:18...
# 963   {'public': {'startDateTime': '2024-02-26T11:00...
# 1079  {'public': {'startDateTime': '2023-11-09T09:00...
# 584   {'public': {'startDateTime': '2023-12-12T11:00...
# 1569  {'public': {'startDateTime': '2023-11-14T19:00...
#
#                                                   dates  \
# 1098  {'access': {'startDateTime': '2024-12-08T18:00...
# 963   {'start': {'localDate': '2024-08-15', 'localTi...
# 1079  {'access': {'startDateTime': '2024-06-23T19:30...
# 584   {'start': {'localDate': '2024-04-13', 'localTi...
# 1569  {'start': {'localDate': '2024-07-07', 'localTi...
#
#                                         classifications  \
# 1098  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 963   [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 1079  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 584   [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 1569  [{'primary': True, 'segment': {'id': 'KZFzniwn...
#
#                                promoter  \
# 1098                Rubén Rosas Sánchez
# 963                 Only Tickets, S.L.,
# 1079             Qué Lindo Sería, A.I.E
# 584   Artisti-K Prod. Mus. y Cult, S.L.
# 1569        Tú lo haces posible, A.I.E.
#
#                                             priceRanges  \
# 1098  [{'type': 'standard', 'currency': 'EUR', 'min'...
# 963   [{'type': 'standard', 'currency': 'EUR', 'min'...
# 1079  [{'type': 'standard including fees', 'currency...
# 584   [{'type': 'standard', 'currency': 'EUR', 'min'...
# 1569  [{'type': 'standard including fees', 'currency...
#
#                                               _embedded         startDateTime  \
# 1098  {'venues': [{'name': 'Sala Razzmatazz 2', 'typ...  2024-12-08T18:00:00Z
# 963   {'venues': [{'name': 'Hï Ibiza', 'type': 'venu...  2024-08-15T21:30:00Z
# 1079  {'venues': [{'name': 'Plaza de Toros de Granad...  2024-06-23T19:30:00Z
# 584   {'venues': [{'name': 'Sala The One', 'type': '...  2024-04-13T19:30:00Z
# 1569  {'venues': [{'name': 'Estadio Santiago Bernabé...  2024-07-07T19:30:00Z
#
#             sales_datetime          end_datetime  min_price  max_price  \
# 1098  2023-08-24T18:18:00Z  2024-12-08T17:00:00Z       27.0       27.0
# 963   2024-02-26T11:00:00Z  2024-08-15T06:00:00Z       90.0       90.0
# 1079  2023-11-09T09:00:00Z  2024-06-23T19:30:00Z       25.0       90.0
# 584   2023-12-12T11:00:00Z  2024-04-13T19:30:00Z       25.0       60.0
# 1569  2023-11-14T19:00:00Z  2024-07-07T19:30:00Z       50.0     1250.0
#
#                 genero          subgnero
# 1098              Rock         Hard Rock
# 963   Dance/Electronic  Dance/Electronic
# 1079              Rock               Pop
# 584               Rock               Pop
# 1569              Rock               Pop

# %%
# Conseguimos reducir el numero de nulos en startDateTime
num_nulos = df_1['startDateTime'].isnull().sum()
num_nulos
# Out:
# 6

# %%
# Todas la filas con nulo en startDateTime es porque no tienen hora de inicio del evento
nulos_dateTime = df_1[df_1['startDateTime'].isnull()]
nulos_dateTime.iloc[5]['dates']
# Out:
# {'start': {'localDate': '2024-05-11',
#   'dateTBD': False,
#   'dateTBA': False,
#   'timeTBA': True,
#   'noSpecificTime': False},
#  'timezone': 'Europe/Madrid',
#  'status': {'code': 'onsale'},
#  'spanMultipleDays': False}

# %%
df_1 = df_1.drop(columns=['sales','dates','classifications','priceRanges'])

# %%
df_1.sample(5)
# Out:
#                                           name  \
# 490                              Calvin Harris
# 682                              Manolo García
# 1391  David Guetta presents F*** me I´m Famous
# 801                                       Ants
# 109                           Miriam Rodríguez
#
#                                promoter  \
# 490                 Only Tickets, S.L.,
# 682        Concert Tour Gestiones, S.L.
# 1391                Only Tickets, S.L.,
# 801                 Only Tickets, S.L.,
# 109   Artisti-K Prod. Mus. y Cult, S.L.
#
#                                               _embedded         startDateTime  \
# 490   {'venues': [{'name': 'Ushuaïa Ibiza', 'type': ...  2024-08-23T15:00:00Z
# 682   {'venues': [{'name': 'Coliseum', 'type': 'venu...  2024-11-09T21:00:00Z
# 1391  {'venues': [{'name': 'Ushuaïa Ibiza', 'type': ...  2024-08-05T15:00:00Z
# 801   {'venues': [{'name': 'Ushuaïa Ibiza', 'type': ...  2024-07-13T13:00:00Z
# 109   {'venues': [{'name': 'Sala The One', 'type': '...  2024-04-13T19:30:00Z
#
#             sales_datetime          end_datetime  min_price  max_price  \
# 490   2024-02-14T17:00:00Z  2024-08-23T06:00:00Z      100.0      100.0
# 682   2023-12-05T14:00:00Z  2024-11-09T22:59:00Z       47.0       52.0
# 1391  2024-02-14T17:00:00Z  2024-08-05T06:00:00Z      100.0      100.0
# 801   2024-02-14T17:30:00Z  2024-07-13T06:00:00Z       50.0       65.0
# 109   2023-12-12T11:00:00Z  2024-04-13T19:30:00Z       25.0       60.0
#
#                 genero          subgnero
# 490   Dance/Electronic  Dance/Electronic
# 682               Rock               Pop
# 1391  Dance/Electronic  Dance/Electronic
# 801   Dance/Electronic  Dance/Electronic
# 109               Rock               Pop

# %% [markdown]
# Exploramos las nuevas columnas que hemos creado.

# %%
generos = df_1['genero'].value_counts()
generos
# Out:
# Dance/Electronic     712
# Rock                 692
# Other                198
# Undefined            107
# Alternative           93
# Hip-Hop/Rap           34
# Music                 25
# World                 25
# Classical             11
# Theatre                6
# Blues                  4
# Pop                    3
# Fairs & Festivals      1
# Name: genero, dtype: int64

# %%
subgeneros = df_1['subgnero'].value_counts()
subgeneros
# Out:
# Dance/Electronic     712
# Pop                  646
# Other                198
# Undefined            107
# Alternative Rock      93
# Hard Rock             46
# Hip-Hop/Rap           34
# Music                 25
# Flamenco              16
# Classical/Vocal       11
# World                  9
# Drama                  6
# Jazz Blues             4
# African Pop            3
# Fairs & Festivals      1
# Name: subgnero, dtype: int64

# %% [markdown]
# Es probable que no encontremos información de los oyenetes de los géneros: Classical, Theatre, Fairs & Festivals. Esta será una de nuestras variables principales por lo que al no tenerla no podremos usar estos datos como prueba.

# %%
generos = ['Classical', 'Theatre', 'Fairs & Festivals']
df_1 = df_1[~df_1['genero'].isin(generos)]
len(df_1)
# Out:
# 1893

# %% [markdown]
# Ahora queda subdividir la columna _embedded que se ha leido del csv como string. Necesitamos tranformarla en el diccionario que era para poder obtener más variables. Esta es una muestra de los valores que tiene:

# %%
df_1.iloc[1]['_embedded']
# Out:
# "{'venues': [{'name': 'Auditorio Starlite', 'type': 'venue', 'id': 'Z598xZ2qZkAek', 'test': False, 'url': 'https://www.ticketmaster.es/venue/auditorio-starlite-marbella-entradas/starlitmar/114', 'locale': 'en-us', 'postalCode': '29602', 'timezone': 'Europe/Madrid', 'city': {'name': 'Marbella'}, 'state': {'name': 'Málaga'}, 'country': {'name': 'Spain', 'countryCode': 'ES'}, 'address': {'line1': 'Calle Albinoni, s/n. Cantera de Nagüeles'}, 'location': {'longitude': '-4.94999', 'latitude': '36.5266'}, 'upcomingEvents': {'mfx-es': 33, '_total': 33, '_filtered': 0}, '_links': {'self': {'href': '/discovery/v2/venues/Z598xZ2qZkAek?locale=en-us'}}}], 'attractions': [{'name': 'Sheryl Crow', 'type': 'attraction', 'id': 'K8vZ91713kV', 'test': False, 'url': 'https://www.ticketmaster.co.nz/sheryl-crow-tickets/artist/752821', 'locale': 'en-us', 'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/channel/UC89Lupwwv9ANeuxfDRXo7mQ'}], 'twitter': [{'url': 'https://twitter.com/SherylCrow'}], 'itunes': [{'url': 'https://music.apple.com/us/artist/sheryl-crow/58757'}], 'facebook': [{'url': 'https://www.facebook.com/sherylcrow'}], 'wiki': [{'url': 'https://en.wikipedia.org/wiki/Sheryl_Crow'}], 'spotify': [{'url': 'https://open.spotify.com/artist/4TKTii6gnOnUXQHyuo9JaD'}], 'instagram': [{'url': 'https://www.instagram.com/SherylCrow'}], 'musicbrainz': [{'id': '80ccfede-c258-4575-a7ad-c982e9932e0f'}], 'homepage': [{'url': 'http://www.sherylcrow.com/'}]}, 'aliases': ['cheryl crow', 'sheryl crow', 'cheryl crowe', 'sheryl crowe'], 'images': [{'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_RECOMENDATION_16_9.jpg', 'width': 100, 'height': 56, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_EVENT_DETAIL_PAGE_16_9.jpg', 'width': 205, 'height': 115, 'fallback': False}, {'ratio': '4_3', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_CUSTOM.jpg', 'width': 305, 'height': 225, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/031/e6d62c69-9726-4b41-ad88-6d3f49300031_SOURCE', 'width': 2426, 'height': 1617, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_RETINA_PORTRAIT_3_2.jpg', 'width': 640, 'height': 427, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_TABLET_LANDSCAPE_LARGE_16_9.jpg', 'width': 2048, 'height': 1152, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_RETINA_PORTRAIT_16_9.jpg', 'width': 640, 'height': 360, 'fallback': False}, {'ratio': '4_3', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_SOURCE', 'width': 2048, 'height': 1536, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_ARTIST_PAGE_3_2.jpg', 'width': 305, 'height': 203, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_TABLET_LANDSCAPE_3_2.jpg', 'width': 1024, 'height': 683, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_TABLET_LANDSCAPE_16_9.jpg', 'width': 1024, 'height': 576, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/204/241e5bed-f759-414f-91ba-5fdb55840204_RETINA_LANDSCAPE_16_9.jpg', 'width': 1136, 'height': 639, 'fallback': False}], 'classifications': [{'primary': True, 'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'}, 'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'}, 'subGenre': {'id': 'KZazBEonSMnZfZ7v6dt', 'name': 'Alternative Rock'}, 'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}, 'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}, 'family': False}], 'upcomingEvents': {'ticketnet': 1, 'mfx-es': 2, 'tmr': 1, 'ticketmaster': 23,  ...

# %% [markdown]
# Al igual que antes reemplazamos las comillas simples por comillas dobles y los valores True, False a true, false. Hacemos estas modificaciones y se lo devolvemos al dataframe con el que estamos trabajando (df_1)

# %%
em = df_1['_embedded']
col = em.str.replace("'", '"')
col = col.str.replace("True", 'true')
col = col.str.replace("False", 'false')
df_1['_embedded'] = col

# %% [markdown]
# Ahora arreglamos el los valores de la columna _embedded en una nueva columna llamada columna_json. En caso de que sea incapaz de cargar la columna, devolverá None

# %%
# def load_json(json_str):
#   str_fixed =  json_str.replace('""','/')
#   try:
#       json_object = json.loads(str_fixed)
#       return json_object
#   except json.JSONDecodeError as e:
#       return 1

# df_1['columna_json'] = df_1['_embedded'].apply(load_json)
# df_1 = df_1.reset_index(drop=True)

# %%
# conteo_de_unos_col1 = (df_1['columna_json'] == 1).sum()
# conteo_de_unos_col1
# Out:
# 71

# %%
# df_sinEm = df_1.loc[df_1['columna_json'] == 1]
# df_sinEm = df_sinEm.reset_index(drop=True)
# df_sinEm.sample(5)
# Out:
#                                         name             promoter  \
# 69  David Guetta presents F*** me I´m Famous  Only Tickets, S.L.,
# 7   David Guetta presents F*** me I´m Famous  Only Tickets, S.L.,
# 63  David Guetta presents F*** me I´m Famous  Only Tickets, S.L.,
# 1                           ZENOBIA + DEBLER  Rubén Rosas Sánchez
# 64  David Guetta presents F*** me I´m Famous  Only Tickets, S.L.,
#
#                                             _embedded         startDateTime  \
# 69  {"venues": [{"name": "Ushuaïa Ibiza", "type": ...  2024-09-30T15:00:00Z
# 7   {"venues": [{"name": "Ushuaïa Ibiza", "type": ...  2024-09-16T15:00:00Z
# 63  {"venues": [{"name": "Ushuaïa Ibiza", "type": ...  2024-08-19T15:00:00Z
# 1   {"venues": [{"name": "Salamandra Sala 1", "typ...  2024-06-01T17:30:00Z
# 64  {"venues": [{"name": "Ushuaïa Ibiza", "type": ...  2024-08-26T15:00:00Z
#
#           sales_datetime          end_datetime  min_price  max_price  \
# 69  2024-02-14T17:00:00Z  2024-09-30T06:00:00Z      100.0      100.0
# 7   2024-02-14T17:00:00Z  2024-09-16T06:00:00Z      100.0      100.0
# 63  2024-02-14T17:00:00Z  2024-08-19T06:00:00Z      100.0      100.0
# 1   2023-11-13T09:00:00Z  2024-06-01T17:30:00Z       22.0       22.0
# 64  2024-02-14T17:00:00Z  2024-08-26T06:00:00Z      100.0      100.0
#
#               genero          subgnero columna_json
# 69  Dance/Electronic  Dance/Electronic            1
# 7   Dance/Electronic  Dance/Electronic            1
# 63  Dance/Electronic  Dance/Electronic            1
# 1               Rock         Hard Rock            1
# 64  Dance/Electronic  Dance/Electronic            1

# %%
df_sinEm.iloc[20]['_embedded']
# Out:
# '{"venues": [{"name": "Ushuaïa Ibiza", "type": "venue", "id": "Z598xZ2qZ7vaF", "test": false, "url": "https://www.ticketmaster.es/venue/ushuaia-ibiza-ibiza-entradas/houshuasjt/115", "locale": "en-us", "postalCode": "07817", "timezone": "Europe/Madrid", "city": {"name": "Ibiza"}, "state": {"name": "Balearic Islands"}, "country": {"name": "Spain", "countryCode": "ES"}, "address": {"line1": "Platja d""en Bossa, S/N"}, "location": {"longitude": "1.40524", "latitude": "38.88346"}, "upcomingEvents": {"mfx-es": 121, "_total": 121, "_filtered": 0}, "_links": {"self": {"href": "/discovery/v2/venues/Z598xZ2qZ7vaF?locale=en-us"}}}], "attractions": [{"name": "F**k Me I"m Famous", "type": "attraction", "id": "K8vZ917fBuf", "test": false, "url": "https://www.ticketmaster.co.uk/fk-me-im-famous-tickets/artist/2255516", "locale": "en-us", "images": [{"ratio": "16_9", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_RETINA_LANDSCAPE_16_9.jpg", "width": 1136, "height": 639, "fallback": false, "attribution": "Fuck24"}, {"ratio": "16_9", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_RECOMENDATION_16_9.jpg", "width": 100, "height": 56, "fallback": false, "attribution": "Fuck24"}, {"ratio": "16_9", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_TABLET_LANDSCAPE_LARGE_16_9.jpg", "width": 2048, "height": 1152, "fallback": false, "attribution": "Fuck24"}, {"ratio": "16_9", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_TABLET_LANDSCAPE_16_9.jpg", "width": 1024, "height": 576, "fallback": false, "attribution": "Fuck24"}, {"ratio": "3_2", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_RETINA_PORTRAIT_3_2.jpg", "width": 640, "height": 427, "fallback": false, "attribution": "Fuck24"}, {"ratio": "3_2", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_TABLET_LANDSCAPE_3_2.jpg", "width": 1024, "height": 683, "fallback": false, "attribution": "Fuck24"}, {"ratio": "16_9", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_EVENT_DETAIL_PAGE_16_9.jpg", "width": 205, "height": 115, "fallback": false, "attribution": "Fuck24"}, {"ratio": "16_9", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_SOURCE", "width": 2426, "height": 1365, "fallback": false, "attribution": "Fuck24"}, {"ratio": "16_9", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_RETINA_PORTRAIT_16_9.jpg", "width": 640, "height": 360, "fallback": false, "attribution": "Fuck24"}, {"ratio": "4_3", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_CUSTOM.jpg", "width": 305, "height": 225, "fallback": false, "attribution": "Fuck24"}, {"ratio": "3_2", "url": "https://s1.ticketm.net/dam/a/27a/242c91ba-9d54-45fd-888b-c527e822e27a_ARTIST_PAGE_3_2.jpg", "width": 305, "height": 203, "fallback": false, "attribution": "Fuck24"}], "classifications": [{"primary": true, "segment": {"id": "KZFzniwnSyZfZ7v7nJ", "name": "Music"}, "genre": {"id": "KnvZfZ7vAvF", "name": "Dance/Electronic"}, "subGenre": {"id": "KZazBEonSMnZfZ7vAJ1", "name": "Club Dance"}, "type": {"id": "KZAyXgnZfZ7v7nI", "name": "Undefined"}, "subType": {"id": "KZFzBErXgnZfZ7v7lJ", "name": "Undefined"}, "family": false}], "upcomingEvents": {"mfx-es": 19, "_total": 19, "_filtered": 0}, "_links": {"self": {"href": "/discovery/v2/attractions/K8vZ917fBuf?locale=en-us"}}}, {"name": "David Guetta", "type": "attraction", "id": "K8vZ917G-90", "test": false, "url": "https://www.ticketmaster.co.uk/david-guetta-tickets/artist/1109508", "locale": "en-us", "externalLinks": {"youtube": [{"url": "https://www.youtube.com/user/davidguettavevo"}, {"url": "https://www.youtube.com/user/davidguetta"}], "twitter": [{"url": "https://twitter.com/davidguetta"}], "itunes": [{"url": "https://music.apple.com/us/artist/david-guetta/5557599"}], "facebook": [{"url": "https://www.facebook.com/Davi ...

# %%
def load_json(json_str):
    try:
        json_object = json.loads(json_str)
        return json_object
    except json.JSONDecodeError as e:
        return None

df_1['columna_json'] = df_1['_embedded'].apply(load_json)

print('Valores None en la columna',df_1['columna_json'].isna().sum())
# Out:
# Valores None en la columna 699

# %% [markdown]
# Como usaremos las variables de la columna_json creamos un nuevo dataframe (df_2) con las filas que no tiene none en la columna_json.

# %%
df_2 = df_1.dropna(subset=['columna_json'])
len(df_2)
# Out:
# 1194

# %% [markdown]
# Ahora dividimos la columna_json en nuevas variables.

# %%
def genre_event(fila):
  if 'columna_json' in fila and 'attractions' in fila['columna_json'] and fila['columna_json']['attractions']:
    return fila['columna_json']['attractions'][0]['classifications'][0]['genre']['name']
  else:
    return None

def subgenre_event(fila):
  if 'columna_json' in fila and 'attractions' in fila['columna_json'] and fila['columna_json']['attractions']:
    return fila['columna_json']['attractions'][0]['classifications'][0]['subGenre']['name']
  else:
    return None

def type_event(fila):
  if 'columna_json' in fila and 'attractions' in fila['columna_json'] and fila['columna_json']['attractions']:
    return fila['columna_json']['attractions'][0]['classifications'][0]['type']['name']
  else:
    return None

def subtype_event(fila):
  if 'columna_json' in fila and 'attractions' in fila['columna_json'] and fila['columna_json']['attractions']:
    return fila['columna_json']['attractions'][0]['classifications'][0]['subType']['name']
  else:
    return None

def name(fila):
  if 'columna_json' in fila and 'attractions' in fila['columna_json'] and fila['columna_json']['attractions']:
    return fila['columna_json']['attractions'][0]['name']
  else:
    return None

def venue_name(fila):
  return fila['columna_json']['venues'][0]['name']

def venue_city(fila):
  return fila['columna_json']['venues'][0]['city']['name']

def venue_state(fila):
  return fila['columna_json']['venues'][0]['state']['name']

def venue_country(fila):
  return fila['columna_json']['venues'][0]['country']['name']

def links(fila):
  if 'columna_json' in fila and 'attractions' in fila['columna_json']:
    attractions = fila['columna_json']['attractions']
    if attractions and 'externalLinks' in attractions[0]:
      return attractions[0]['externalLinks']
  return None

def num_links(fila):
  if fila['links'] == None:
    return 0
  else:
    return len(fila['links'].keys())

# %%
k = df_2.iloc[0]['links'].keys()
len(k)

df_2['num_links'] = df_2.apply(num_links, axis=1)
# Out:
# <ipython-input-59-b56f10bce27e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['num_links'] = df_2.apply(num_links, axis=1)

# %%
df_2.sample(5)
# Out:
#                                                    name  \
# 928                      Rulo y la Contrabanda - Tour 5
# 130                                          Fran Perea
# 436   Kamelot + Ad Infinitum + Blackbriar + Frozen C...
# 1047                                             Emilia
# 282                      Rulo y la Contrabanda - Tour 5
#
#                                 promoter  \
# 928   Promociones Musicales Get In, S.L.
# 130   Promociones Musicales Get In, S.L.
# 436                  Sergio Solís Gálvez
# 1047             Azul es mi color, A.I.E
# 282   Promociones Musicales Get In, S.L.
#
#                                               _embedded         startDateTime  \
# 928   {"venues": [{"name": "Andén 56", "type": "venu...  2024-04-13T21:00:00Z
# 130   {"venues": [{"name": "Sala Camelot", "type": "...  2024-03-08T20:00:00Z
# 436   {"venues": [{"name": "Sala Santana 27", "type"...  2024-10-22T18:00:00Z
# 1047  {"venues": [{"name": "Coliseum", "type": "venu...  2024-06-22T20:30:00Z
# 282   {"venues": [{"name": "Sala Industrial Copera",...  2024-05-18T20:00:00Z
#
#             sales_datetime          end_datetime  min_price  max_price genero  \
# 928   2023-10-19T10:00:00Z  2024-04-13T20:00:00Z       30.0       30.0   Rock
# 130   2023-09-26T10:00:00Z  2024-03-08T20:00:00Z       25.0       38.0   Rock
# 436   2024-02-16T10:00:00Z  2024-10-22T16:30:00Z       32.0       32.0   Rock
# 1047  2024-01-24T15:00:00Z  2024-06-22T20:00:00Z       35.0       90.0   Rock
# 282   2023-10-19T10:00:00Z  2024-05-18T19:00:00Z       28.0       28.0   Rock
#
#        subgnero  ... genre          subgenre        type          subtype  \
# 928         Pop  ...  Rock               Pop  Individual  Singer/Vocalist
# 130         Pop  ...   Pop         Pop Vocal   Undefined        Undefined
# 436   Hard Rock  ...  Rock  Alternative Rock   Undefined        Undefined
# 1047        Pop  ...   Pop               Pop   Undefined        Undefined
# 282         Pop  ...  Rock               Pop  Individual  Singer/Vocalist
#
#                    VenueName  VenueCity  VenueState VenueCountry  \
# 928                 Andén 56     Burgos      Burgos        Spain
# 130             Sala Camelot  Salamanca   Salamanca        Spain
# 436          Sala Santana 27     Bilbao      Biscay        Spain
# 1047                Coliseum   A Coruña  La Corunna        Spain
# 282   Sala Industrial Copera    Granada     Granada        Spain
#
#                                                   links num_links
# 928   {'youtube': [{'url': 'https://www.youtube.com/...         6
# 130                                                None         0
# 436   {'youtube': [{'url': 'https://www.youtube.com/...         8
# 1047                                               None         0
# 282   {'youtube': [{'url': 'https://www.youtube.com/...         6
#
# [5 rows x 22 columns]

# %%
df_2['nameArtist'] = df_2.apply(name, axis=1).copy()
df_2.loc[:, 'genre'] = df_2.apply(genre_event, axis=1).copy()
df_2.loc[:, 'subgenre'] = df_2.apply(subgenre_event, axis=1).copy()
df_2.loc[:, 'type'] = df_2.apply(type_event, axis=1).copy()
df_2.loc[:, 'subtype'] = df_2.apply(subtype_event, axis=1).copy()
df_2['VenueName'] = df_2.apply(venue_name, axis=1)
df_2['VenueCity'] = df_2.apply(venue_city, axis=1)
df_2['VenueState'] = df_2.apply(venue_state, axis=1)
df_2['VenueCountry'] = df_2.apply(venue_country, axis=1)

df_2['links'] = df_2.apply(links, axis=1)

df_2.reset_index()

# %%
df_2 = df_2.drop(columns=['_embedded','columna_json','VenueCountry',])

# %%
import requests

# Tu API key y secret obtenidos en el paso anterior
client_id = '3e082f0f2dd240c1beb66c9705a663a5'
client_secret = 'd3dd1f7886eb4ba4aa5a76c9095120d7'

# URL de la API de Spotify para obtener un token de acceso
token_url = 'https://accounts.spotify.com/api/token'

# Parámetros necesarios para obtener el token de acceso
token_params = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
}

# Obtener el token de acceso
token_response = requests.post(token_url, data=token_params)
token_data = token_response.json()

# Verificar si se obtuvo correctamente el token
if 'access_token' in token_data:
    access_token = token_data['access_token']

    # Lista de nombres de artistas
    artist_names = [i for i in df_2['nameArtist'].unique()]

    # URL de la API de Spotify para buscar al artista
    search_url = 'https://api.spotify.com/v1/search'

    # Configurar el diccionario para almacenar los IDs de los artistas
    artist_ids = {}

    # Configurar la cabecera con el token de acceso
    headers = {
        'Authorization': f'Bearer {access_token}',
    }

    # Hacer la solicitud de búsqueda del artista para cada nombre en la lista
    for artist_name in artist_names:
        search_params = {
            'q': artist_name,
            'type': 'artist',
        }

        # Hacer la solicitud de búsqueda del artista
        search_response = requests.get(search_url, params=search_params, headers=headers)
        search_data = search_response.json()

        # Verificar si se encontraron resultados para el artista en 2022
        if 'artists' in search_data and 'items' in search_data['artists']:
            for artist in search_data['artists']['items']:
                if 'name' in artist and artist['name'] == artist_name:
                    # Agregar la entrada al diccionario
                    artist_ids[artist_name] = artist['id']
                    break
            else:
                print(f"No se encontraron resultados para {artist_name} en 2022")
        else:
            print(f'No se encontró al artista {artist_name}')

    # Imprimir el diccionario resultante

else:
    print('Error al obtener el token de acceso')
    print(token_data)
# Out:
# No se encontraron resultados para UB40 Featuring Ali Campbell in memory of Astro en 2022
# No se encontraron resultados para Ballet Flamenco Sara Baras en 2022
# No se encontraron resultados para Australian Pink Floyd Show en 2022
# No se encontraron resultados para Rulo y la Contrabanda en 2022
# No se encontraron resultados para Dystinct en 2022
# No se encontraron resultados para Vida Records & Friends en 2022
# No se encontraron resultados para Álvaro de Luna en 2022
# No se encontraron resultados para Pablo Rouss en 2022
# No se encontró al artista None
# No se encontraron resultados para Primavera Pop en 2022
# No se encontraron resultados para Tan Biónica en 2022
# No se encontraron resultados para MANÁ en 2022
# No se encontraron resultados para gREAT sTRAITS en 2022
# No se encontraron resultados para Rozalen en 2022
# No se encontraron resultados para Stingers en 2022
# No se encontraron resultados para Mago De Oz en 2022
# No se encontraron resultados para Tributo a Queen en 2022
# No se encontraron resultados para Juanjo Monserrat & Mansfeld en 2022
# No se encontraron resultados para Paula Mattheus en Concierto en 2022
# No se encontraron resultados para CALIFATO ¾ en 2022
# No se encontraron resultados para Ninos Mutantes en 2022
# No se encontraron resultados para Milo J en 2022
# No se encontraron resultados para El Langui en 2022
# No se encontraron resultados para Kadec Santa Ana en 2022
# No se encontraron resultados para NieR: Orchestra Concert en 2022
# No se encontraron resultados para Premier - La gran quedada en 2022
# No se encontraron resultados para Eva Ruíz en 2022
# No se encontraron resultados para Flor Bertotti en 2022
# No se encontraron resultados para Ballet Nacional De Espana en 2022
# No se encontraron resultados para Carlos Pinana en 2022
# No se encontraron resultados para SO-LA-NA en 2022
# No se encontraron resultados para The Music of Hans Zimmer & More en 2022
# No se encontraron resultados para The Magical Music of Harry Potter - Live in Concert en 2022
# No se encontraron resultados para Eurovision on tour en 2022
# No se encontraron resultados para HIVERNACLE en 2022
# No se encontraron resultados para Barcelona Beach Festival en 2022
# No se encontraron resultados para Gipsy Kings featuring Nicolas Reyes en 2022
# No se encontraron resultados para Lion Rock Fest en 2022
# No se encontraron resultados para Abba The New Experience en 2022

# %%
df_ids= pd.DataFrame([[key, artist_ids[key]] for key in artist_ids.keys()], columns=['Name', 'Ids'])
df_ids
# Out:
#                 Name                     Ids
# 0       Jamie Cullum  3XxxEq6BREC57nCWXbQZ7o
# 1        Sheryl Crow  4TKTii6gnOnUXQHyuo9JaD
# 2             Aitana  7eLcDZDYHXZCebtQmVFL25
# 3    Christian Nodal  0XwVARXT135rw8lyw1EeWP
# 4          Take That  1XgFuvRd7r5g0h844A5ZUQ
# ..               ...                     ...
# 153          Karol G  4asJQrazucWu3Zy5R7B164
# 154     Simple Minds  6hN9F0iuULZYWXppob22Aj
# 155    Ronald Borjas  1c8m6rFeA6QIhImbIaZ7k2
# 156        Front 242  2tyMOS8xKREgpEwHnLc6EX
# 157          Garbage  6S0GHTqz5sxK5f9HtLXn9q
#
# [158 rows x 2 columns]

# %%
# Tu API key y secret obtenidos en el paso anterior
client_id = '3e082f0f2dd240c1beb66c9705a663a5'
client_secret = 'd3dd1f7886eb4ba4aa5a76c9095120d7'

# URL de la API de Spotify para obtener un token de acceso
token_url = 'https://accounts.spotify.com/api/token'

# Parámetros necesarios para obtener el token de acceso
token_params = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
}

# Obtener el token de acceso
token_response = requests.post(token_url, data=token_params)
token_data = token_response.json()

# Verificar si se obtuvo correctamente el token
if 'access_token' in token_data:
    access_token = token_data['access_token']

    # DataFrame con la columna de IDs de los artistas
    df_artist_ids = pd.DataFrame({'Ids': df_ids['Ids']})

    # URL base de la API de Spotify para obtener información de varios artistas
    artists_url = 'https://api.spotify.com/v1/artists'

    # Configurar la cabecera con el token de acceso
    headers = {
        'Authorization': f'Bearer {access_token}',
    }

    # Lista para almacenar los números de oyentes de cada artista
    followers_counts = []

    # Hacer la solicitud para obtener información de cada artista
    for artist_id in df_artist_ids['Ids']:
        artist_url = f'{artists_url}/{artist_id}'
        artist_response = requests.get(artist_url, headers=headers)
        artist_data = artist_response.json()

        # Verificar si se obtuvo correctamente la información del artista
        if 'followers' in artist_data:
            followers_count = artist_data['followers']['total']
            followers_counts.append(followers_count)
        else:
            followers_counts.append(None)  # Si no se encuentra el número de oyentes, agregar None

    # Agregar la columna de números de oyentes al DataFrame
    df_artist_ids['followers_count'] = followers_counts

    # Mostrar el DataFrame resultante

else:
    print('Error al obtener el token de acceso')
    print(token_data)

df_artist_ids
# Out:
#                         Ids  followers_count
# 0    3XxxEq6BREC57nCWXbQZ7o           515169
# 1    4TKTii6gnOnUXQHyuo9JaD          1122227
# 2    7eLcDZDYHXZCebtQmVFL25          2900501
# 3    0XwVARXT135rw8lyw1EeWP         14152890
# 4    1XgFuvRd7r5g0h844A5ZUQ          1279968
# ..                      ...              ...
# 153  4asJQrazucWu3Zy5R7B164             3554
# 154  6hN9F0iuULZYWXppob22Aj          1937668
# 155  1c8m6rFeA6QIhImbIaZ7k2           106262
# 156  2tyMOS8xKREgpEwHnLc6EX           139991
# 157  6S0GHTqz5sxK5f9HtLXn9q          1170338
#
# [158 rows x 2 columns]

# %%
df_ids['Oyentes Mensuales']=df_artist_ids['followers_count']
df_ids
# Out:
#                 Name                     Ids  Oyentes Mensuales
# 0       Jamie Cullum  3XxxEq6BREC57nCWXbQZ7o             515169
# 1        Sheryl Crow  4TKTii6gnOnUXQHyuo9JaD            1122227
# 2             Aitana  7eLcDZDYHXZCebtQmVFL25            2900501
# 3    Christian Nodal  0XwVARXT135rw8lyw1EeWP           14152890
# 4          Take That  1XgFuvRd7r5g0h844A5ZUQ            1279968
# ..               ...                     ...                ...
# 153          Karol G  4asJQrazucWu3Zy5R7B164               3554
# 154     Simple Minds  6hN9F0iuULZYWXppob22Aj            1937668
# 155    Ronald Borjas  1c8m6rFeA6QIhImbIaZ7k2             106262
# 156        Front 242  2tyMOS8xKREgpEwHnLc6EX             139991
# 157          Garbage  6S0GHTqz5sxK5f9HtLXn9q            1170338
#
# [158 rows x 3 columns]

# %%
df_ids.rename(columns={'Name': 'nameArtist'}, inplace=True)
df_ids
# Out:
#           nameArtist                     Ids  Oyentes Mensuales
# 0       Jamie Cullum  3XxxEq6BREC57nCWXbQZ7o             515169
# 1        Sheryl Crow  4TKTii6gnOnUXQHyuo9JaD            1122227
# 2             Aitana  7eLcDZDYHXZCebtQmVFL25            2900501
# 3    Christian Nodal  0XwVARXT135rw8lyw1EeWP           14152890
# 4          Take That  1XgFuvRd7r5g0h844A5ZUQ            1279968
# ..               ...                     ...                ...
# 153          Karol G  4asJQrazucWu3Zy5R7B164               3554
# 154     Simple Minds  6hN9F0iuULZYWXppob22Aj            1937668
# 155    Ronald Borjas  1c8m6rFeA6QIhImbIaZ7k2             106262
# 156        Front 242  2tyMOS8xKREgpEwHnLc6EX             139991
# 157          Garbage  6S0GHTqz5sxK5f9HtLXn9q            1170338
#
# [158 rows x 3 columns]

# %%
df3 = df_2.merge( df_ids, on='nameArtist', how='left')

# %%
df3
# Out:
#                      name                   promoter         startDateTime  \
# 0            Jamie Cullum    Tickex Experience, S.L.  2024-06-14T20:00:00Z
# 1             Sheryl Crow    Tickex Experience, S.L.  2024-06-21T20:00:00Z
# 2                  Aitana    Tickex Experience, S.L.  2024-06-22T20:00:00Z
# 3         Christian Nodal    Tickex Experience, S.L.  2024-07-13T20:00:00Z
# 4               Take That    Tickex Experience, S.L.  2024-07-14T20:00:00Z
# ...                   ...                        ...                   ...
# 1189            Hombres G    Tickex Experience, S.L.  2024-08-31T20:00:00Z
# 1190      Christian Nodal   JI Entertainment, A.I.E.  2024-07-05T19:00:00Z
# 1191  The Teskey Brothers  Live Nation España S.A.U.  2024-07-19T19:00:00Z
# 1192  The Teskey Brothers  Live Nation España S.A.U.  2024-07-20T19:00:00Z
# 1193        Ronald Borjas           La Sordera, S.L.  2024-09-26T19:30:00Z
#
#               end_datetime  min_price  max_price     genero   subgnero  \
# 0     2024-06-12T21:59:00Z      30.01      59.29      Music      Music
# 1     2024-06-19T21:59:00Z      30.01      80.00      Music      Music
# 2     2024-06-20T21:59:00Z      65.18     146.43      Music      Music
# 3     2024-07-11T21:59:00Z      30.01      79.29      Music      Music
# 4     2024-07-12T21:59:00Z      55.36     155.36      Music      Music
# ...                    ...        ...        ...        ...        ...
# 1189  2024-08-29T21:59:00Z      39.29     127.68  Undefined  Undefined
# 1190  2024-07-05T19:00:00Z      25.00      90.00      World      World
# 1191  2024-07-19T19:00:00Z      30.00      30.00      Other      Other
# 1192  2024-07-20T19:00:00Z      30.00      30.00      Other      Other
# 1193  2024-09-26T18:30:00Z      44.00      44.00      Other      Other
#
#                nameArtist  genre          subgenre        type    subtype  \
# 0            Jamie Cullum   Jazz              Jazz   Undefined  Undefined
# 1             Sheryl Crow   Rock  Alternative Rock   Undefined  Undefined
# 2                  Aitana    Pop         Pop Vocal   Undefined  Undefined
# 3         Christian Nodal  World             Latin  Individual   Musician
# 4               Take That   Rock               Pop   Undefined  Undefined
# ...                   ...    ...               ...         ...        ...
# 1189            Hombres G    Pop          Pop Rock       Group       Band
# 1190      Christian Nodal  World             Latin  Individual   Musician
# 1191  The Teskey Brothers  Blues             Blues       Group       Band
# 1192  The Teskey Brothers  Blues             Blues       Group       Band
# 1193        Ronald Borjas  Latin             Latin  Individual   Musician
#
#                VenueName  VenueCity VenueState                     Ids  \
# 0     Auditorio Starlite   Marbella     Málaga  3XxxEq6BREC57nCWXbQZ7o
# 1     Auditorio Starlite   Marbella     Málaga  4TKTii6gnOnUXQHyuo9JaD
# 2     Auditorio Starlite   Marbella     Málaga  7eLcDZDYHXZCebtQmVFL25
# 3     Auditorio Starlite   Marbella     Málaga  0XwVARXT135rw8lyw1EeWP
# 4     Auditorio Starlite   Marbella     Málaga  1XgFuvRd7r5g0h844A5ZUQ
# ...                  ...        ...        ...                     ...
# 1189  Auditorio Starlite   Marbella     Málaga  60uh2KYYSCqAgJNxcU4DA0
# 1190       WiZink Center     Madrid     Madrid  0XwVARXT135rw8lyw1EeWP
# 1191          La Riviera     Madrid     Madrid  2nTjd2lNo1GVEfXM3bCnsh
# 1192   Sala Razzmatazz 1  Barcelona  Barcelona  2nTjd2lNo1GVEfXM3bCnsh
# 1193   Sala Razzmatazz 1  Barcelona  Barcelona  1c8m6rFeA6QIhImbIaZ7k2
#
#       Oyentes Mensuales
# 0              515169.0
# 1             1122227.0
# 2             2900501.0
# 3            14152890.0
# 4             1279968.0
# ...                 ...
# 1189          4129389.0
# 1190         14152890.0
# 1191           677143.0
# 1192           677143.0
# 1193           106262.0
#
# [1194 rows x 18 columns]

# %%
# Configura tu clave de API de Last.fm
LASTFM_API_KEY = "d3668e7b9ace955aaefafa6e262386ba"
ARTIST_NAMES = [i for i in df_2['nameArtist'].dropna().unique()]
DATE = "03-03-2024"  # Ajusta según sea necesario

for artist_name in ARTIST_NAMES:
    # Construye la URL para solicitar datos de Last.fm para cada artista
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={artist_name}&api_key={LASTFM_API_KEY}&format=json"

    # Realiza la solicitud a la API de Last.fm
    response = requests.get(url)
    data = response.json()

    # Extrae el número de oyentes en la fecha específica (si está disponible en la respuesta)
    if "artist" in data and "stats" in data["artist"]:
        listeners = data["artist"]["stats"]["listeners"]
        print(f"Número de oyentes de {artist_name}: {listeners}")
    else:
        print(f"No se encontró información para {artist_name}.")
# Out:
# Número de oyentes de Jamie Cullum: 1211111
# Número de oyentes de Sheryl Crow: 1597120
# Número de oyentes de Aitana: 151420
# Número de oyentes de Christian Nodal: 162438
# Número de oyentes de Take That: 1042323
# Número de oyentes de Tom Jones: 1136498
# Número de oyentes de Luis Miguel: 507030
# Número de oyentes de Diana Krall: 1230424
# Número de oyentes de Los Secretos: 112161
# Número de oyentes de Antonio José: 30750
# Número de oyentes de HAUSER: 27654
# Número de oyentes de Miguel Poveda: 40434
# Número de oyentes de Gordo: 39311
# No se encontró información para UB40 Featuring Ali Campbell in memory of Astro.
# Número de oyentes de La Oreja de Van Gogh: 492063
# Número de oyentes de Abraham Mateo: 112603
# No se encontró información para Ballet Flamenco Sara Baras.
# Número de oyentes de Siempre Así: 1962
# Número de oyentes de Marc Seguí: 110449
# Número de oyentes de Dead Poet Society: 152633
# Número de oyentes de Dreamcatcher: 412954
# Número de oyentes de Manolo Garcia: 12042
# Número de oyentes de Australian Pink Floyd Show: 14
# Número de oyentes de Hens: 19061
# Número de oyentes de Café Quijano: 91441
# Número de oyentes de Fran Perea: 21539
# Número de oyentes de Rulo y la Contrabanda: 16757
# Número de oyentes de IAMDDB: 154701
# Número de oyentes de The 1975: 1971313
# Número de oyentes de Gonzalo Alhambra: 374
# Número de oyentes de Nothing But Thieves: 790872
# Número de oyentes de Dystinct: 40860
# Número de oyentes de La Bien Querida: 65275
# Número de oyentes de Burning: 31419
# Número de oyentes de Miriam Rodriguez: 61
# Número de oyentes de Sober: 29873
# Número de oyentes de Walls: 65209
# Número de oyentes de Depeche Mode: 3556612
# Número de oyentes de The Clockworks: 27758
# No se encontró información para Vida Records & Friends.
# Número de oyentes de Álvaro de Luna: 23315
# Número de oyentes de Mother Mother: 1253867
# Número de oyentes de Madison Beer: 943009
# No se encontró información para Pablo Rouss.
# Número de oyentes de Pol Granch: 46999
# Número de oyentes de Niall Horan: 993300
# Número de oyentes de Paul Alone: 7752
# Número de oyentes de Hermanos Gutiérrez: 129828
# Número de oyentes de Fletcher: 522833
# Número de oyentes de The Warning: 77384
# Número de oyentes de MARLON: 25950
# Número de oyentes de ENOL: 8448
# Número de oyentes de The Rose: 315410
# Número de oyentes de Cruz Cafuné: 59892
# Número de oyentes de Sasha Velour: 712
# Número de oyentes de Tom Odell: 1450812
# No se encontró información para Primavera Pop.
# Número de oyentes de JP Saxe: 518375
# Número de oyentes de Benjamin Ingrosso: 133245
# Número de oyentes de Celtas Cortos: 91303
# Número de oyentes de Nil Moliner: 26864
# Número de oyentes de Miguel Mateos: 79967
# Número de oyentes de La Sonrisa De Julia: 31188
# Número de oyentes de Charlie USG: 6421
# Número de oyentes de Mikel Erentxun: 91680
# Número de oyentes de ITZY: 668364
# Número de oyentes de Lil Yachty: 1200030
# Número de oyentes de Antoñito Molina: 1906
# Número de oyentes de Tan Biónica: 1395
# Número de oyentes de Tate McRae: 1161139
# Número de oyentes de Jonas Brothers: 1610416
# Número de oyentes de Thirty Seconds To Mars: 671634
# Número de oyentes de Taylor Swift: 4523312
# Número de oyentes de Andrés Calamaro: 351739
# Número de oyentes de IVE: 617959
# Número de oyentes de El Barrio: 37935
# Número de oyentes de MANÁ: 596676
# Número de oyentes de Marc Anthony: 627065
# Número de oyentes de Camilo: 258030
# Número de oyentes de Queens of the Stone Age: 3122197
# Número de oyentes de Olivia Rodrigo: 2030239
# Número de oyentes de Danza Invisible: 52085
# Número de oyentes de Morat: 204180
# Número de oyentes de Emilia: 310901
# Número de oyentes de Kany Garcia: 14726
# Número de oyentes de Bunbury: 53401
# Número de oyentes de Hozier: 2210292
# Número de oyentes de Pearl Jam: 3471172
# Número de oyentes de The Breeders: 918264
# Número de oyentes de Pixies: 3464129
# Número de oyentes de Fonseca: 166211
# No se encontró información para gREAT sTRAITS.
# Número de oyentes de María Peláe: 7941
# Número de oyentes de Marcus King: 78875
# Número de oyentes de Carin Leon: 111944
# Número de oyentes de Jacob Collier: 359264
# Número de oyentes de Rozalen: 40
# Número de oyentes de Stingers: 701
# Número de oyentes de Supersuckers: 117381
# Número de oyentes de Mago De Oz: 1711
# Número de oyentes de The Answer: 116650
# Número de oyentes de Tributo a Queen: 239
# Número de oyentes de AC/DC: 3728425
# Número de oyentes de Zenobia: 12693
# Número de oyentes de Maiden United: 5113
# Número de oyentes de Kamelot: 494154
# Número de oyentes de Orphaned Land: 163470
# Número de oyentes de Das Ich: 135376
# Número de oyentes de Rojuu: 90180
# No se encontró información para Juanjo Monserrat & Mansfeld.
# No se encontró información para Paula Mattheus en Concierto.
# Número de oyentes de Las Novias: 950
# Número de oyentes de Nathan Fake: 345932
# Número de oyentes de CALIFATO ¾: 16225
# Número de oyentes de Patriarchy: 12408
# Número de oyentes de Isaac Delusion: 185013
# Número de oyentes de Trisomie 21: 57382
# Número de oyentes de The New Raemon: 50272
# Número de oyentes de Pink Turns Blue: 129065
# Número de oyentes de Niños Del Brasil: 997
# Número de oyentes de Future Islands: 744298
# Número de oyentes de Izaro: 7072
# Número de oyentes de The Cat Empire: 470169
# Número de oyentes de Ninos Mutantes: 13
# Número de oyentes de Crystal Fighters: 744355
# Número de oyentes de Juancho Marqués: 22523
# Número de oyentes de Camela: 37728
# Número de oyentes de Milo J: 80168
# Número de oyentes de Víctor Martín: 866
# Número de oyentes de El Langui: 1272
# Número de oyentes de El Kanka: 36089
# Número de oyentes de Aleman: 78269
# No se encontró información para Kadec Santa Ana.
# Número de oyentes de Shawn James: 116563
# No se encontró información para Funzo & Baby Loud.
# No se encontró información para NieR: Orchestra Concert.
# Número de oyentes de El Pau: 607
# Número de oyentes de DJ Nano: 8917
# Número de oyentes de Delaporte: 26387
# No se encontró información para Premier - La gran quedada.
# Número de oyentes de Yung Sarria: 13639
# Número de oyentes de Lord Apex: 121780
# Número de oyentes de Kaizers Orchestra: 167375
# Número de oyentes de Rawayana: 67063
# Número de oyentes de Jolie Holland: 168518
# Número de oyentes de Ha*Ash: 101471
# Número de oyentes de The Tyets: 9437
# Número de oyentes de ElGrandeToto: 25922
# Número de oyentes de La Plazuela: 6681
# Número de oyentes de Kontravoid: 48559
# Número de oyentes de The Change: 31885
# Número de oyentes de Jorge Celedon: 12717
# Número de oyentes de Parra for Cuva: 310299
# Número de oyentes de Chumi DJ: 1179
# Número de oyentes de Eva Ruíz: 4
# Número de oyentes de Carmen Boza: 8807
# Número de oyentes de Duki: 183970
# Número de oyentes de Big Time Rush: 555833
# Número de oyentes de Vanesa Martín: 33538
# Número de oyentes de Estopa: 263875
# Número de oyentes de Flor Bertotti: 41
# Número de oyentes de Myke Towers: 343310
# Número de oyentes de Keane: 3177085
# Número de oyentes de Ballet Nacional De Espana: 3
# Número de oyentes de Carlos Pinana: 5
# No se encontró información para SO-LA-NA.
# Número de oyentes de Pitingo: 30184
# Número de oyentes de Ana Mena: 79060
# Número de oyentes de Hombres G: 356873
# Número de oyentes de Cultura Profética: 144100
# No se encontró información para The Music of Hans Zimmer & More.
# No se encontró información para The Magical Music of Harry Potter - Live in Concert.
# Número de oyentes de Miguel Rios: 45902
# Número de oyentes de Carlos Vives: 474964
# No se encontró información para Eurovision on tour.
# Número de oyentes de Joan Dausà: 8235
# Número de oyentes de Nada Surf: 1033727
# Número de oyentes de The Tallest Man On Earth: 1058540
# Número de oyentes de Mudhoney: 669208
# Número de oyentes de Foy Vance: 302489
# Número de oyentes de New Model Army: 205762
# Número de oyentes de Kazy Lambist: 144565
# No se encontró información para HIVERNACLE.
# Número de oyentes de Nicki Nicole: 166413
# Número de oyentes de Cano: 14154
# Número de oyentes de Bartan Beat: 1
# No se encontró información para Barcelona Beach Festival.
# No se encontró información para Gipsy Kings featuring Nicolas Reyes.
# Número de oyentes de The Teskey Brothers: 180659
# Número de oyentes de Karol G: 873654
# Número de oyentes de Simple Minds: 1617530
# Número de oyentes de Ronald Borjas: 1795
# No se encontró información para Lion Rock Fest.
# No se encontró información para Abba The New Experience.
# Número de oyentes de Front 242: 270811
# Número de oyentes de Garbage: 1910595

# %%
# Configura tu clave de API de Last.fm
LASTFM_API_KEY = "d3668e7b9ace955aaefafa6e262386ba"
ARTIST_NAMES = [i for i in df_2['nameArtist'].dropna().unique()]
DATE = "03-03-2024"  # Ajusta según sea necesario

# Listas para almacenar los datos
artist_list = []
listeners_list = []

for artist_name in ARTIST_NAMES:
    # Construye la URL para solicitar datos de Last.fm para cada artista
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={artist_name}&api_key={LASTFM_API_KEY}&format=json"

    # Realiza la solicitud a la API de Last.fm
    response = requests.get(url)
    data = response.json()

    # Extrae el número de oyentes en la fecha específica (si está disponible en la respuesta)
    if "artist" in data and "stats" in data["artist"]:
        listeners = data["artist"]["stats"]["listeners"]
        artist_list.append(artist_name)
        listeners_list.append(listeners)
    else:
        print(f"No se encontró información para {artist_name}.")

# Crea un DataFrame a partir de las listas de datos recopilados
df = pd.DataFrame({"Artist": artist_list, "Listeners": listeners_list})

# Muestra el DataFrame
df
# Out:
# No se encontró información para UB40 Featuring Ali Campbell in memory of Astro.
# No se encontró información para Ballet Flamenco Sara Baras.
# No se encontró información para Vida Records & Friends.
# No se encontró información para Pablo Rouss.
# No se encontró información para Primavera Pop.
# No se encontró información para gREAT sTRAITS.
# No se encontró información para Juanjo Monserrat & Mansfeld.
# No se encontró información para Paula Mattheus en Concierto.
# No se encontró información para Kadec Santa Ana.
# No se encontró información para Funzo & Baby Loud.
# No se encontró información para NieR: Orchestra Concert.
# No se encontró información para Premier - La gran quedada.
# No se encontró información para SO-LA-NA.
# No se encontró información para The Music of Hans Zimmer & More.
# No se encontró información para The Magical Music of Harry Potter - Live in Concert.
# No se encontró información para Eurovision on tour.
# No se encontró información para HIVERNACLE.
# No se encontró información para Barcelona Beach Festival.
# No se encontró información para Gipsy Kings featuring Nicolas Reyes.
# No se encontró información para Lion Rock Fest.
# No se encontró información para Abba The New Experience.
#               Artist Listeners
# 0       Jamie Cullum   1211111
# 1        Sheryl Crow   1597120
# 2             Aitana    151420
# 3    Christian Nodal    162438
# 4          Take That   1042323
# ..               ...       ...
# 170          Karol G    873654
# 171     Simple Minds   1617530
# 172    Ronald Borjas      1795
# 173        Front 242    270811
# 174          Garbage   1910595
#
# [175 rows x 2 columns]

# %%
df=df.rename(columns={'Artist':'nameArtist'})

# %%
df4 = df3.merge(df, on='nameArtist', how='left')

# %%
df4=df4.drop(columns='Ids')

# %%
df4=df4.rename(columns={'Oyentes Mensuales':'Spotify_Mensuales','Listeners':'Last.fm_Oyentes', 'end_datetime':'endSalesTime'})
df4
# Out:
#                      name                   promoter         startDateTime  \
# 0            Jamie Cullum    Tickex Experience, S.L.  2024-06-14T20:00:00Z
# 1             Sheryl Crow    Tickex Experience, S.L.  2024-06-21T20:00:00Z
# 2                  Aitana    Tickex Experience, S.L.  2024-06-22T20:00:00Z
# 3         Christian Nodal    Tickex Experience, S.L.  2024-07-13T20:00:00Z
# 4               Take That    Tickex Experience, S.L.  2024-07-14T20:00:00Z
# ...                   ...                        ...                   ...
# 1189            Hombres G    Tickex Experience, S.L.  2024-08-31T20:00:00Z
# 1190      Christian Nodal   JI Entertainment, A.I.E.  2024-07-05T19:00:00Z
# 1191  The Teskey Brothers  Live Nation España S.A.U.  2024-07-19T19:00:00Z
# 1192  The Teskey Brothers  Live Nation España S.A.U.  2024-07-20T19:00:00Z
# 1193        Ronald Borjas           La Sordera, S.L.  2024-09-26T19:30:00Z
#
#               endSalesTime  min_price  max_price     genero   subgnero  \
# 0     2024-06-12T21:59:00Z      30.01      59.29      Music      Music
# 1     2024-06-19T21:59:00Z      30.01      80.00      Music      Music
# 2     2024-06-20T21:59:00Z      65.18     146.43      Music      Music
# 3     2024-07-11T21:59:00Z      30.01      79.29      Music      Music
# 4     2024-07-12T21:59:00Z      55.36     155.36      Music      Music
# ...                    ...        ...        ...        ...        ...
# 1189  2024-08-29T21:59:00Z      39.29     127.68  Undefined  Undefined
# 1190  2024-07-05T19:00:00Z      25.00      90.00      World      World
# 1191  2024-07-19T19:00:00Z      30.00      30.00      Other      Other
# 1192  2024-07-20T19:00:00Z      30.00      30.00      Other      Other
# 1193  2024-09-26T18:30:00Z      44.00      44.00      Other      Other
#
#                nameArtist  genre          subgenre        type    subtype  \
# 0            Jamie Cullum   Jazz              Jazz   Undefined  Undefined
# 1             Sheryl Crow   Rock  Alternative Rock   Undefined  Undefined
# 2                  Aitana    Pop         Pop Vocal   Undefined  Undefined
# 3         Christian Nodal  World             Latin  Individual   Musician
# 4               Take That   Rock               Pop   Undefined  Undefined
# ...                   ...    ...               ...         ...        ...
# 1189            Hombres G    Pop          Pop Rock       Group       Band
# 1190      Christian Nodal  World             Latin  Individual   Musician
# 1191  The Teskey Brothers  Blues             Blues       Group       Band
# 1192  The Teskey Brothers  Blues             Blues       Group       Band
# 1193        Ronald Borjas  Latin             Latin  Individual   Musician
#
#                VenueName  VenueCity VenueState  Spotify_Mensuales  \
# 0     Auditorio Starlite   Marbella     Málaga           515169.0
# 1     Auditorio Starlite   Marbella     Málaga          1122227.0
# 2     Auditorio Starlite   Marbella     Málaga          2900501.0
# 3     Auditorio Starlite   Marbella     Málaga         14152890.0
# 4     Auditorio Starlite   Marbella     Málaga          1279968.0
# ...                  ...        ...        ...                ...
# 1189  Auditorio Starlite   Marbella     Málaga          4129389.0
# 1190       WiZink Center     Madrid     Madrid         14152890.0
# 1191          La Riviera     Madrid     Madrid           677143.0
# 1192   Sala Razzmatazz 1  Barcelona  Barcelona           677143.0
# 1193   Sala Razzmatazz 1  Barcelona  Barcelona           106262.0
#
#      Last.fm_Oyentes
# 0            1211111
# 1            1597120
# 2             151420
# 3             162438
# 4            1042323
# ...              ...
# 1189          356873
# 1190          162438
# 1191          180659
# 1192          180659
# 1193            1795
#
# [1194 rows x 18 columns]

# %%
# quitar filas con NaN y convertir a tipo int las columnas de oyentes
df4 = df4.dropna(subset=['Last.fm_Oyentes'])
df4['Last.fm_Oyentes'] = df4['Last.fm_Oyentes'].astype(int)
df4 = df4.dropna(subset=['Spotify_Mensuales'])
df4['Spotify_Mensuales'] = df4['Spotify_Mensuales'].astype(int)
# Out:
# <ipython-input-40-9fc935128bfe>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Last.fm_Oyentes'] = df4['Last.fm_Oyentes'].astype(int)

# %%
df4
# Out:
#                      name                   promoter         startDateTime  \
# 0            Jamie Cullum    Tickex Experience, S.L.  2024-06-14T20:00:00Z
# 1             Sheryl Crow    Tickex Experience, S.L.  2024-06-21T20:00:00Z
# 2                  Aitana    Tickex Experience, S.L.  2024-06-22T20:00:00Z
# 3         Christian Nodal    Tickex Experience, S.L.  2024-07-13T20:00:00Z
# 4               Take That    Tickex Experience, S.L.  2024-07-14T20:00:00Z
# ...                   ...                        ...                   ...
# 1189            Hombres G    Tickex Experience, S.L.  2024-08-31T20:00:00Z
# 1190      Christian Nodal   JI Entertainment, A.I.E.  2024-07-05T19:00:00Z
# 1191  The Teskey Brothers  Live Nation España S.A.U.  2024-07-19T19:00:00Z
# 1192  The Teskey Brothers  Live Nation España S.A.U.  2024-07-20T19:00:00Z
# 1193        Ronald Borjas           La Sordera, S.L.  2024-09-26T19:30:00Z
#
#               endSalesTime  min_price  max_price     genero   subgnero  \
# 0     2024-06-12T21:59:00Z      30.01      59.29      Music      Music
# 1     2024-06-19T21:59:00Z      30.01      80.00      Music      Music
# 2     2024-06-20T21:59:00Z      65.18     146.43      Music      Music
# 3     2024-07-11T21:59:00Z      30.01      79.29      Music      Music
# 4     2024-07-12T21:59:00Z      55.36     155.36      Music      Music
# ...                    ...        ...        ...        ...        ...
# 1189  2024-08-29T21:59:00Z      39.29     127.68  Undefined  Undefined
# 1190  2024-07-05T19:00:00Z      25.00      90.00      World      World
# 1191  2024-07-19T19:00:00Z      30.00      30.00      Other      Other
# 1192  2024-07-20T19:00:00Z      30.00      30.00      Other      Other
# 1193  2024-09-26T18:30:00Z      44.00      44.00      Other      Other
#
#                nameArtist  genre          subgenre        type    subtype  \
# 0            Jamie Cullum   Jazz              Jazz   Undefined  Undefined
# 1             Sheryl Crow   Rock  Alternative Rock   Undefined  Undefined
# 2                  Aitana    Pop         Pop Vocal   Undefined  Undefined
# 3         Christian Nodal  World             Latin  Individual   Musician
# 4               Take That   Rock               Pop   Undefined  Undefined
# ...                   ...    ...               ...         ...        ...
# 1189            Hombres G    Pop          Pop Rock       Group       Band
# 1190      Christian Nodal  World             Latin  Individual   Musician
# 1191  The Teskey Brothers  Blues             Blues       Group       Band
# 1192  The Teskey Brothers  Blues             Blues       Group       Band
# 1193        Ronald Borjas  Latin             Latin  Individual   Musician
#
#                VenueName  VenueCity VenueState  Spotify_Mensuales  \
# 0     Auditorio Starlite   Marbella     Málaga             515169
# 1     Auditorio Starlite   Marbella     Málaga            1122227
# 2     Auditorio Starlite   Marbella     Málaga            2900501
# 3     Auditorio Starlite   Marbella     Málaga           14152890
# 4     Auditorio Starlite   Marbella     Málaga            1279968
# ...                  ...        ...        ...                ...
# 1189  Auditorio Starlite   Marbella     Málaga            4129389
# 1190       WiZink Center     Madrid     Madrid           14152890
# 1191          La Riviera     Madrid     Madrid             677143
# 1192   Sala Razzmatazz 1  Barcelona  Barcelona             677143
# 1193   Sala Razzmatazz 1  Barcelona  Barcelona             106262
#
#       Last.fm_Oyentes
# 0             1211111
# 1             1597120
# 2              151420
# 3              162438
# 4             1042323
# ...               ...
# 1189           356873
# 1190           162438
# 1191           180659
# 1192           180659
# 1193             1795
#
# [1027 rows x 18 columns]

# %%
print(df4['type'].unique())
#df4['subgnero'].unique()
print(df4['subtype'].unique())
#count_nan = df4['max_price'].isnull().sum()
#print(count_nan)
# Out:
# ['Undefined' 'Individual' 'Event Style' 'Group']
# ['Undefined' 'Musician' 'Concert' 'Individual' 'Singer/Vocalist' 'Band'
#  'Performer' 'Artist' 'Tribute Band' 'Group']

# %% [markdown]
# PASAMOS A FICHERO PARQUET

# %%
df4.to_parquet('EventPeak.parquet')

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=44c29f796d2aeb04666c6ce040bd42f3ffc377cea962046bdf9bda1b49eddb68
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark.sql import SparkSession

# Crear una sesión de Spark
spark = SparkSession.builder \
    .appName("Guardar DataFrame como Parquet") \
    .getOrCreate()

# Suponiendo que ya tienes el DataFrame df4
df_spark = spark.createDataFrame(df4)

# Guardar el DataFrame como archivo Parquet
df_spark.write.parquet('archivo.parquet')

# Cerrar la sesión de Spark
spark.stop()

# %%
# el fichero parquet se encuentra en la ruta:
#   /content/drive/MyDrive/PD1/EventPeak.parquet

# %% [markdown]
# IDEAS PARA DIVIDIR EN DISTINTOS PARQUETS

# %%
# POR CIUDAD
df_2['VenueCity'].value_counts()
# Out:
# Madrid                     376
# Barcelona                  260
# Marbella                   122
# Bilbao                      40
# Valencia                    31
# Sevilla                     30
# A Coruña                    25
# Murcia                      23
# Granada                     21
# Santander                   18
# Zaragoza                    17
# Mislata                     17
# Pamplona/Iruña              17
# Fuengirola                  12
# Burgos                      11
# Santiago de Compostela      11
# Málaga                      11
# Salamanca                   11
# Córdoba                      9
# Palma de Mallorca            8
# Barakaldo                    7
# Vigo                         7
# Gijón                        7
# Chiclana de la Frontera      7
# Valladolid                   6
# Alicante                     6
# Donostia/San Sebastián       6
# Montmeló                     5
# Zamora                       5
# La Unión                     5
# León                         5
# Adeje                        4
# Almería                      4
# San Vicente del Raspeig      3
# Palencia                     3
# Cádiz                        3
# Badajoz                      3
# Tafalla                      3
# Jaén                         3
# O Grove                      2
# Cáceres                      2
# Bigastro                     2
# Vitoria-Gasteiz              2
# Logroño                      2
# Mairena del Aljarafe         2
# Roquetas de Mar              2
# Don Benito                   2
# Albacete                     2
# Avilés                       2
# Castellón de la Plana        2
# Mérida                       2
# Toledo                       1
# Plasencia                    1
# Huelva                       1
# San Miguel de Abona          1
# Elche                        1
# Santa Cruz de Tenerife       1
# Laudio/Llodio                1
# Guadalajara                  1
# Name: VenueCity, dtype: int64

# %%
# POR COMUNIDAD AUTÓNOMA
df_2['VenueState'].value_counts()
# Out:
# Madrid                    376
# Barcelona                 265
# Málaga                    145
# Valencia                   48
# Biscay                     47
# La Corunna                 36
# Seville                    32
# Murcia                     28
# Granada                    21
# Navarre                    20
# Cantabria                  18
# Saragossa                  17
# Alacant                    12
# Burgos                     11
# Salamanca                  11
# Cádiz                      10
# Pontevedra                  9
# Córdoba                     9
# Asturias                    9
# Balearic Islands            8
# Badajoz                     7
# Valladolid                  6
# Almería                     6
# Guipuscoa                   6
# Santa Cruz de Tenerife      6
# León                        5
# Zamora                      5
# Araba                       3
# Cáceres                     3
# Palencia                    3
# Jaén                        3
# Castellón                   2
# Albacete                    2
# La Rioja                    2
# Huelva                      1
# Guadalajara                 1
# Toledo                      1
# Name: VenueState, dtype: int64

# %% [markdown]
# - EXPLORACIÓN DE LOS DATOS

# %%
# Calculamos estadísticas descriptivas para las variables numéricas
descripcion_numericas = df4.describe()

# Calculamos la moda para las variables categóricas
moda_categoricas = df4.mode()

# Visualizamos las estadísticas descriptivas para las variables numéricas
print("Estadísticas Descriptivas para Variables Numéricas:")
print(descripcion_numericas)

# Visualizamos la moda para las variables categóricas
print("\nModa para Variables Categóricas:")
print(moda_categoricas)
# Out:
# Estadísticas Descriptivas para Variables Numéricas:
#          min_price    max_price  Spotify_Mensuales  Last.fm_Oyentes
# count  1024.000000  1024.000000       1.027000e+03     1.027000e+03
# mean     37.096162   103.724238       3.930081e+06     4.759258e+05
# std      22.381562   348.913542       9.305252e+06     8.545122e+05
# min      10.000000    10.000000       1.000000e+00     1.000000e+00
# 25%      25.000000    25.000000       8.220600e+04     2.765400e+04
# 50%      31.625000    40.000000       4.962120e+05     1.166500e+05
# 75%      43.000000    90.000000       3.710820e+06     5.070300e+05
# max     179.460000  6000.000000       1.036210e+08     4.523312e+06
#
# Moda para Variables Categóricas:
#      name                   promoter         startDateTime  \
# 0  Camilo  Live Nation España S.A.U.  2024-03-17T20:00:00Z
#
#            endSalesTime  min_price  max_price genero subgnero nameArtist  \
# 0  2024-04-05T19:00:00Z       25.0       25.0   Rock      Pop     Camilo
#
#   genre subgenre       type    subtype           VenueName VenueCity  \
# 0  Rock      Pop  Undefined  Undefined  Auditorio Starlite    Madrid
#
#   VenueState  Spotify_Mensuales  Last.fm_Oyentes
# 0     Madrid           18565418           258030

# %%
correlation_matrix = df4.corr()
print(correlation_matrix)
# Out:
#                    min_price  max_price  Spotify_Mensuales  Last.fm_Oyentes
# min_price           1.000000   0.458644           0.359271         0.360269
# max_price           0.458644   1.000000           0.197695         0.112720
# Spotify_Mensuales   0.359271   0.197695           1.000000         0.429205
# Last.fm_Oyentes     0.360269   0.112720           0.429205         1.000000
# <ipython-input-50-fefc644f5dc9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df4.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, vmin=-1, vmax=1)
plt.title('Matriz de Correlación')
plt.show()

# %%
import missingno as msno
msno.matrix(df4)
# Out:
# <Axes: >

# %% [markdown]
# Parece que solo startDateTime tiene nulos.
#
# Aparte hay 3 filas que tienen nulos también en min_price y max_price

# %%
#msno.heatmap(df4)

# %% [markdown]
# Podemos detectar si una columna depende de otra, utilizando el test $\mathcal{X}^2$.

# %%
contingencias=pd.crosstab(index=df4.startDateTime,columns=df4["min_price"])
contingencias
# Out:
# min_price             10.00   12.00   13.00   15.00   16.00   17.00   18.00   \
# startDateTime
# 2023-03-21T19:30:00Z       0       0       0       0       0       0       0
# 2023-03-22T21:00:00Z       0       0       0       0       0       0       0
# 2023-04-04T21:00:00Z       0       0       0       0       0       0       0
# 2023-04-05T20:00:00Z       0       0       0       0       0       0       0
# 2023-04-11T20:00:00Z       0       0       0       0       0       0       0
# ...                      ...     ...     ...     ...     ...     ...     ...
# 2024-11-30T21:00:00Z       0       0       0       0       0       0       0
# 2024-12-08T18:00:00Z       0       0       0       0       0       0       0
# 2024-12-12T19:30:00Z       0       0       0       0       0       0       0
# 2024-12-13T19:30:00Z       0       0       0       0       0       0       0
# 2024-12-14T20:00:00Z       0       0       0       0       0       0       0
#
# min_price             19.00   20.00   22.00   ...  75.00   76.79   80.00   \
# startDateTime                                 ...
# 2023-03-21T19:30:00Z       0       3       0  ...       0       0       0
# 2023-03-22T21:00:00Z       0       3       0  ...       0       0       0
# 2023-04-04T21:00:00Z       0       3       0  ...       0       0       0
# 2023-04-05T20:00:00Z       0       3       0  ...       0       0       0
# 2023-04-11T20:00:00Z       0       4       0  ...       0       0       0
# ...                      ...     ...     ...  ...     ...     ...     ...
# 2024-11-30T21:00:00Z       0       0       0  ...       0       0       0
# 2024-12-08T18:00:00Z       0       0       0  ...       0       0       0
# 2024-12-12T19:30:00Z       0       0       4  ...       0       0       0
# 2024-12-13T19:30:00Z       0       0       2  ...       0       0       0
# 2024-12-14T20:00:00Z       0       0       0  ...       0       0       0
#
# min_price             81.00   87.50   105.00  138.04  141.10  150.00  179.46
# startDateTime
# 2023-03-21T19:30:00Z       0       0       0       0       0       0       0
# 2023-03-22T21:00:00Z       0       0       0       0       0       0       0
# 2023-04-04T21:00:00Z       0       0       0       0       0       0       0
# 2023-04-05T20:00:00Z       0       0       0       0       0       0       0
# 2023-04-11T20:00:00Z       0       0       0       0       0       0       0
# ...                      ...     ...     ...     ...     ...     ...     ...
# 2024-11-30T21:00:00Z       0       0       0       0       0       0       0
# 2024-12-08T18:00:00Z       0       0       0       0       0       0       0
# 2024-12-12T19:30:00Z       0       0       0       0       0       0       0
# 2024-12-13T19:30:00Z       0       0       0       0       0       0       0
# 2024-12-14T20:00:00Z       0       0       0       0       0       0       0
#
# [322 rows x 69 columns]

# %% [markdown]
# Esto era para ver primero cómo se relaciona la variable objetivo con una columna nominal. Pasamos a calcular el test:

# %%
from scipy.stats import chi2_contingency

# este es el test
ChiSqResult = chi2_contingency(contingencias)
ChiSqResult
# Out:
# Chi2ContingencyResult(statistic=52946.0279380173, pvalue=0.0, dof=21828, expected_freq=array([[0.00878906, 0.03222656, 0.046875  , ..., 0.00292969, 0.00878906,
#         0.02636719],
#        [0.00878906, 0.03222656, 0.046875  , ..., 0.00292969, 0.00878906,
#         0.02636719],
#        [0.00878906, 0.03222656, 0.046875  , ..., 0.00292969, 0.00878906,
#         0.02636719],
#        ...,
#        [0.01171875, 0.04296875, 0.0625    , ..., 0.00390625, 0.01171875,
#         0.03515625],
#        [0.00585938, 0.02148438, 0.03125   , ..., 0.00195312, 0.00585938,
#         0.01757812],
#        [0.00585938, 0.02148438, 0.03125   , ..., 0.00195312, 0.00585938,
#         0.01757812]]))

# %% [markdown]
# Como  $H_0$  = No hay correlación entre las variables, y tenemos que p!>0.05, se rechaza la hipótesis nula y se concluye que hay una asociación significativa entre las variables. \
# Así, podemos probar la relación de cada variable categórica con las variables objetivos.

# %%
sns.histplot(data=df4, hue="startDateTime",x="min_price",stat="count", multiple="stack", legend= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-68f9c1db61de> in <cell line: 1>()
# ----> 1 sns.histplot(data=df4, hue="startDateTime",x="min_price",stat="count", multiple="stack", legend= False)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# PROBAR PARA NAMEARTIST

# %%
contingencias=pd.crosstab(index=df4.nameArtist,columns=df4["min_price"])
contingencias
# Out:
# min_price      10.00   12.00   13.00   15.00   16.00   17.00   18.00   19.00   \
# nameArtist
# AC/DC               0       0       0       0       0       0       0       0
# Abraham Mateo       0       0       0       0       0       0       0       0
# Aitana              0       0       0       0       0       0       0       0
# Aleman              0       0       0       0       0       0       0       0
# Ana Mena            0       0       0       0       0       0       0       0
# ...               ...     ...     ...     ...     ...     ...     ...     ...
# Vanesa Martín       0       0       0       0       0       0       0       0
# Víctor Martín       0       6       6       0       0       0       0       0
# Walls               0       0       0       0       0       0       0       0
# Yung Sarria         0       2       0       0       0       0       0       0
# Zenobia             0       0       0       0       0       0       0       0
#
# min_price      20.00   22.00   ...  75.00   76.79   80.00   81.00   87.50   \
# nameArtist                     ...
# AC/DC               0       0  ...       0       0       0       0       0
# Abraham Mateo       0       0  ...       0       0       0       0       0
# Aitana              0       0  ...       0       0       0       0       0
# Aleman              0       4  ...       0       0       0       0       0
# Ana Mena            0       0  ...       0       0       0       0       0
# ...               ...     ...  ...     ...     ...     ...     ...     ...
# Vanesa Martín       0       0  ...       0       0       0       0       0
# Víctor Martín       0       0  ...       0       0       0       0       0
# Walls               0       0  ...       0       0       0       0       0
# Yung Sarria         0       0  ...       0       0       0       0       0
# Zenobia             0       2  ...       0       0       0       0       0
#
# min_price      105.00  138.04  141.10  150.00  179.46
# nameArtist
# AC/DC               4       0       0       0       0
# Abraham Mateo       0       0       0       0       0
# Aitana              0       0       0       0       0
# Aleman              0       0       0       0       0
# Ana Mena            0       0       0       0       0
# ...               ...     ...     ...     ...     ...
# Vanesa Martín       0       0       0       0       0
# Víctor Martín       0       0       0       0       0
# Walls               0       0       0       0       0
# Yung Sarria         0       0       0       0       0
# Zenobia             0       0       0       0       0
#
# [156 rows x 69 columns]

# %%
# este es el test
ChiSqResult = chi2_contingency(contingencias)
ChiSqResult
# Out:
# Chi2ContingencyResult(statistic=35682.62722965887, pvalue=0.0, dof=10540, expected_freq=array([[0.01171875, 0.04296875, 0.0625    , ..., 0.00390625, 0.01171875,
#         0.03515625],
#        [0.00878906, 0.03222656, 0.046875  , ..., 0.00292969, 0.00878906,
#         0.02636719],
#        [0.03222656, 0.11816406, 0.171875  , ..., 0.01074219, 0.03222656,
#         0.09667969],
#        ...,
#        [0.0234375 , 0.0859375 , 0.125     , ..., 0.0078125 , 0.0234375 ,
#         0.0703125 ],
#        [0.00585938, 0.02148438, 0.03125   , ..., 0.00195312, 0.00585938,
#         0.01757812],
#        [0.00585938, 0.02148438, 0.03125   , ..., 0.00195312, 0.00585938,
#         0.01757812]]))

# %%
sns.histplot(data=df4, hue="nameArtist",x="min_price",stat="count", multiple="stack", legend=False)
# Out:
# <Axes: xlabel='min_price', ylabel='Count'>
